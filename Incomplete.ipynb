# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_excel(r"D:\MSE\1year\ASSIGNMENTS\ECOTRIX ASGNMT\monthly data.xls", sheet_name="jan")

# %%
df.head(15)
# Out:
#          Date   Metals   Oil & Gas   IT Sector  Health Care  \
# 0  2005-01-01   6103.98     3063.92    2570.09      2701.68
# 1  2006-01-01   7131.20     4435.95    3749.20      3290.65
# 2  2007-01-01   9283.17     6297.64    5297.17      3804.30
# 3  2008-01-01  15312.92    11032.16    3710.11      3603.52
# 4  2009-01-01   5100.14     6064.11    2236.51      2713.84
# 5  2010-01-01  15962.05     9596.24    4977.71      4765.14
# 6  2011-01-01  16115.67     9459.45    6371.10      6236.88
# 7  2012-01-01  11498.86     8711.71    5777.71      6336.02
# 8  2013-01-01  10606.13     9359.16    6393.63      8016.93
# 9  2014-01-01   9151.57     8453.06    9476.62     10109.76
# 10 2015-01-01  10190.20    10143.20   11178.71     15666.51
# 11 2016-01-01   6894.01     9258.06   11165.05     16304.98
# 12 2017-01-01  11672.32    12838.16    9586.34     14797.01
# 13 2018-01-01  15427.36    16368.16   12556.98     14559.39
# 14 2019-01-01  10958.60    13612.32   15264.10     13881.35
#
# ...

# %%
df.set_index('Date',inplace=True)

# %%
df.head()
# Out:
#              Metals   Oil & Gas   IT Sector  Health Care  Consumer Durables  \
# Date
# 2005-01-01   6103.98     3063.92    2570.09      2701.68            1448.65
# 2006-01-01   7131.20     4435.95    3749.20      3290.65            3148.45
# 2007-01-01   9283.17     6297.64    5297.17      3804.30            3800.93
# 2008-01-01  15312.92    11032.16    3710.11      3603.52            5103.86
# 2009-01-01   5100.14     6064.11    2236.51      2713.84            1777.84
#
#             Fast Moving Consumer   Capital Goods    Bankex      Auto
# Date
# 2005-01-01                1122.01         2985.49   3670.63  2804.58
# 2006-01-01                1741.11         6986.87   5254.89  4506.53
# 2007-01-01                1906.21         9485.79   7260.09  5515.36
# 2008-01-01                2167.34        16387.70  10713.91  4832.48
# 2009-01-01                2032.69         6256.61   4900.06  2500.23

# %%
df.describe()
# Out:
#             Metals     Oil & Gas      IT Sector   Health Care  \
# count     15.000000     15.000000     15.000000     15.000000
# mean   10760.545333   9246.220000   7354.068667   8452.530667
# std     3651.013188   3463.650073   3944.973856   5240.032972
# min     5100.140000   3063.920000   2236.510000   2701.680000
# 25%     8141.385000   7375.350000   4363.455000   3703.910000
# 50%    10606.130000   9359.160000   6371.100000   6336.020000
# 75%    13492.620000  10587.680000  10375.695000  14220.370000
# max    16115.670000  16368.160000  15264.100000  16304.980000
#
#        Consumer Durables  Fast Moving Consumer   Capital Goods        Bankex   \
# count          15.000000              15.000000       15.000000     15.000000
# mean         8220.506000            5212.267333    12034.820000  14369.988667
# std          6513.373793            3474.712648     4733.426407   8789.894027
# min          1448.650000            1122.010000     2985.490000   3670.630000
# ...

# %% [markdown]
# # Step 2: Visualize the Data

# %%
lines = df.plot.line(figsize=(16, 9))

# %%
axes = df.plot.line(figsize=(16, 9), subplots=True)

# %%
from statsmodels.tsa.stattools import adfuller

# %%
test_result=adfuller(df["Auto"])

# %%
#Ho: It is non stationary
#H1: It is stationary

def adfuller_test(Auto):
    result=adfuller(Auto)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )
    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary")
    else:
        print("weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")

# %%
adfuller_test(df['Auto'])
# Out:
# ADF Test Statistic : -0.8850335156217994
# p-value : 0.7928611324906865
# #Lags Used : 5
# Number of Observations Used : 9
# weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary

# %%
df['Auto First Difference'] = df['Auto'] - df['Auto'].shift(1)

# %%
df['Auto'].shift(1)
# Out:
# Date
# 2005-01-01         NaN
# 2006-01-01     2804.58
# 2007-01-01     4506.53
# 2008-01-01     5515.36
# 2009-01-01     4832.48
# 2010-01-01     2500.23
# 2011-01-01     6953.20
# 2012-01-01     8894.58
# 2013-01-01     9241.78
# 2014-01-01    10993.92
# 2015-01-01    11568.87
# 2016-01-01    19985.90
# 2017-01-01    17046.03
# 2018-01-01    21809.24
# 2019-01-01    25945.30
# Name: Auto, dtype: float64

# %%
df['Seasonal First Difference']=df['Auto']-df['Auto'].shift(12)

# %%
df.head()
# Out:
#              Metals   Oil & Gas   IT Sector  Health Care  Consumer Durables  \
# Date
# 2005-01-01   6103.98     3063.92    2570.09      2701.68            1448.65
# 2006-01-01   7131.20     4435.95    3749.20      3290.65            3148.45
# 2007-01-01   9283.17     6297.64    5297.17      3804.30            3800.93
# 2008-01-01  15312.92    11032.16    3710.11      3603.52            5103.86
# 2009-01-01   5100.14     6064.11    2236.51      2713.84            1777.84
#
#             Fast Moving Consumer   Capital Goods    Bankex      Auto  \
# Date
# 2005-01-01                1122.01         2985.49   3670.63  2804.58
# 2006-01-01                1741.11         6986.87   5254.89  4506.53
# 2007-01-01                1906.21         9485.79   7260.09  5515.36
# 2008-01-01                2167.34        16387.70  10713.91  4832.48
# 2009-01-01                2032.69         6256.61   4900.06  2500.23
#
#             Auto First Difference  Seasonal First Difference
# Date
# ...
