# %% [markdown]
# # Matplotlib tutorial Intro

# %% [markdown]
# ###### Notes
# In the graph 'color' is indicated by adding color ='name of the color'.
# Similarly line width of the graph is represented by adding linewidth = no of the width
# alpha refers to the transaparency of the line
# dpi refers to the dots per inches which indicates the pixels of the figure.
# figure size refers to the size of the figure *default figure size is (6.4, 4.8) inches in matplotlib 2
# figsize=(w,h), width and height

# %%
# "Matplotlib is the whole package; pylab is a module in matplotlib"
import numpy as np

# %%
x = np.linspace(0, 10, 25)
print(x)
# Out:
# [ 0.          0.41666667  0.83333333  1.25        1.66666667  2.08333333
#   2.5         2.91666667  3.33333333  3.75        4.16666667  4.58333333
#   5.          5.41666667  5.83333333  6.25        6.66666667  7.08333333
#   7.5         7.91666667  8.33333333  8.75        9.16666667  9.58333333
#  10.        ]

# %%
y = x * x + 2
print(y)
# Out:
# [  2.           2.17361111   2.69444444   3.5625       4.77777778
#    6.34027778   8.25        10.50694444  13.11111111  16.0625
#   19.36111111  23.00694444  27.          31.34027778  36.02777778
#   41.0625      46.44444444  52.17361111  58.25        64.67361111
#   71.44444444  78.5625      86.02777778  93.84027778 102.        ]

# %%
print(np.array([x,y]).reshape(25, 2))
# Out:
# [[  0.           0.41666667]
#  [  0.83333333   1.25      ]
#  [  1.66666667   2.08333333]
#  [  2.5          2.91666667]
#  [  3.33333333   3.75      ]
#  [  4.16666667   4.58333333]
#  [  5.           5.41666667]
#  [  5.83333333   6.25      ]
#  [  6.66666667   7.08333333]
#  [  7.5          7.91666667]
#  [  8.33333333   8.75      ]
#  [  9.16666667   9.58333333]
#  [ 10.           2.        ]
#  [  2.17361111   2.69444444]
#  [  3.5625       4.77777778]
#  [  6.34027778   8.25      ]
#  [ 10.50694444  13.11111111]
#  [ 16.0625      19.36111111]
#  [ 23.00694444  27.        ]
#  [ 31.34027778  36.02777778]
#  [ 41.0625      46.44444444]
#  [ 52.17361111  58.25      ]
#  [ 64.67361111  71.44444444]
#  [ 78.5625      86.02777778]
#  [ 93.84027778 102.        ]]

# %%
print(np.array([x,y]).reshape(25, 2).reshape(2, 25))
# Out:
# [[  0.           0.41666667   0.83333333   1.25         1.66666667
#     2.08333333   2.5          2.91666667   3.33333333   3.75
#     4.16666667   4.58333333   5.           5.41666667   5.83333333
#     6.25         6.66666667   7.08333333   7.5          7.91666667
#     8.33333333   8.75         9.16666667   9.58333333  10.        ]
#  [  2.           2.17361111   2.69444444   3.5625       4.77777778
#     6.34027778   8.25        10.50694444  13.11111111  16.0625
#    19.36111111  23.00694444  27.          31.34027778  36.02777778
#    41.0625      46.44444444  52.17361111  58.25        64.67361111
#    71.44444444  78.5625      86.02777778  93.84027778 102.        ]]

# %%
import matplotlib.pylab as p

# %%
p.plot(x,y,'g')
#'r' or 'b' stands for red color or blue color.

# %%
##Drawing a subgraph
p.subplot(1, 2, 1) # the contents of the brackets represent (rows, columns, indexes)
p.plot(x,y, 'r--') #The third parameter here determines color and line style
p.subplot(1, 2, 2)
p.plot(y,x, 'g*-')
#The above graph (also can be called as canvas) is splitted into two.

# %%
p.subplot(1, 2, 1) 
p.plot(x,y, 'r--') 
p.subplot(1, 2, 1) # In the index part if we add 1 instead of two then the canvas would change into
p.plot(y,x, 'g*-')
# Out:
# <ipython-input-10-8fc6e2efedba>:3: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   p.subplot(1, 2, 1) # In the index part if we add 1 instead of two then the canvas would change into

# %%
p.subplot(1, 1, 1)  # In the columns part if we add 1 instead of two then the canvas would change into
p.plot(x,y, 'r--') 
p.subplot(1, 2, 1)
p.plot(y,x, 'g*-')

# %%
p.subplot(1, 2, 1)  
p.plot(x,y, 'r--') 
p.subplot(2, 2, 2)  #In the rows part if we add 1 instead of two then the canvas would change into
p.plot(y,x, 'g*-')

# %%
p.subplot(1, 2, 1)  
p.plot(x,y, 'r--') 
p.subplot(2, 2, 2)  #In the rows part if we add 1 instead of two then the canvas would change into
p.plot(y,x, 'g*-')
p.subplot(2, 3, 3)  
p.plot(x,y, 'r*-')

# %%
#(1,2,1) and (1,2,2) are significant if we want tiled subplots, without which both the graphs will in the same plot

#for example
p.subplot(1,2,1) #The contents of the brackets represent (rows, columns, indexes)
p.plot(x,y, 'r--')#The third parameter here determines color and line style
p.subplot(1,2,1)
p.plot(y,x,'g*-')
# Out:
# <ipython-input-14-0727e748b74d>:6: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   p.subplot(1,2,1)

# %% [markdown]
# # Operator Description
# fig.add_axes()=initializes subplot a=fig.add_subplot(222)
#
# fig, b=plt.subplots(nrows=3, nclos=2)=Adds subplot
#
# ax=plt.subplots(2,2)=creates subplot

# %%
from matplotlib import pyplot as plt

# %%
fig=plt.figure()
axis=fig.add_axes([0.5, 0.1, 0.8, 0.8]) #control the left, right, width, height of the canvas (from 0 to 1)
axis.plot(x,y, 'r')

# %%
# again we can draw subgraphs
fig, axes=plt.subplots(nrows =1, ncols=2) # submap is of 1 row, 2 columns
for ax in axes:
    ax.plot(x,y, 'r')

# %%
# again we can draw subgraphs
fig, axes=plt.subplots(nrows =1, ncols=3) # submap is of 1 row, 3 columns
for ax in axes:
    ax.plot(x,y, 'r')

# %%
# again we can draw subgraphs
fig, axes=plt.subplots(nrows =2, ncols=1) # submap is of 2 rows, 1 column
for ax in axes:
    ax.plot(x,y, 'r')

# %%
#we can also draw a picture, or graph, inside another graph
fig = plt.figure()
axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # big axes
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3]) # small canvas
axes1.plot(x,y,'r')
axes2.plot(y,x,'g')

# %%
# Just playing with the axes values for the above graph
#we can also draw a picture, or graph, inside another graph
fig = plt.figure()
axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # big axes
axes2 = fig.add_axes([0.2, 0.6, 0.2, 0.2]) # small canvas
axes1.plot(x,y,'r')
axes2.plot(y,x,'g')

# %%
fig = plt.figure(figsize=(16,9))  #new graphic object
fig.add_subplot()
plt.plot(x,y,'r')

# %%
fig = plt.figure(figsize=(16,9), dpi=300)  #new graphic object
fig.add_subplot()
plt.plot(x,y,'r')

# %%
fig = plt.figure(figsize=(16,9), dpi=100)  #new graphic object
fig.add_subplot()
plt.plot(x,y,'r')

# %%
fig, axes = plt.subplots(figsize=(16,9), dpi=50)  #new graphic object
axes.plot(x,y,'r')

# %%
fig, axes = plt.subplots()  #new graphic object
axes.set_title("KGF")
axes.set_xlabel("Story")
axes.set_ylabel("Fight")
axes.plot(x,y,'r')

# %%
fig, axes = plt.subplots() 
axes.set_title("tile")
axes.set_xlabel("exxxx")
axes.set_ylabel("why")
axes.plot(x,x**2)
axes.plot(x,x**3)

# %%
ax.legend(["label1","label2"])
fig, axes = plt.subplots() 
axes.set_title("tile")
axes.set_xlabel("exxxx")
axes.set_ylabel("why")
axes.plot(x,x**2)
axes.plot(x,x**3)
axes.legend(["y=x**2","y=x**3"],loc=2)

# %%
ax.legend(["label1","label2"])
fig, axes = plt.subplots() 
axes.set_title("tile")
axes.set_xlabel("exxxx")
axes.set_ylabel("why")
axes.plot(x,x**2)
axes.plot(x,x**3)
axes.legend(["y=x**2","y=x**3"],loc=6)

# %%
ax.legend(["label1","label2"])
fig, axes = plt.subplots(dpi=200) 
axes.set_title("tile")
axes.set_xlabel("exxxx")
axes.set_ylabel("why")
axes.plot(x,x**2)
axes.plot(x,x**3)
axes.legend(["y=x**2","y=x**3"],loc=6)

# %%
#In matplotlib you can set other properties such as line colors, transparency, and more...
fig, axes = plt.subplots(dpi=150) 
axes.plot(x,x+1, color='red', alpha=0.5) #alpha refers to the transparency of the color.
axes.plot(x,x+2, color='#1155dd')
axes.plot(x,x+3, color='#15cc55')

# %%
#In matplotlib you can set other properties such as line colors, transparency, and more...
fig, axes = plt.subplots(dpi=150) 
axes.plot(x,x**2, color='red', alpha=0.8)
axes.plot(x,x+2, color='blue', alpha=0.5)
axes.plot(x,x+3, color='#15cc55', alpha=0.5)

# %%
fig, ax = plt.subplots(dpi=100) #figsize=(8,4)

#line width
ax.plot(x, x+1, color='blue', linewidth=0.25)
ax.plot(x, x+2, color='blue', linewidth=1)
ax.plot(x, x+3, color='blue', linewidth=1.5)
ax.plot(x, x+4, color='blue', linewidth=2)

# %%
fig, ax = plt.subplots(dpi=100) #figsize=(8,4)

#line width
ax.plot(x, x+1, color='blue', lw=2, linestyle='-')
ax.plot(x, x+2, color='blue', lw=2, linestyle='-.')
ax.plot(x, x+3, color='blue', lw=2, linestyle=':')

# %%
fig, ax = plt.subplots(dpi=100) #figsize=(8,4)

#line width
ax.plot(x, x+1, color='blue', lw=2, linestyle='-')
ax.plot(x, x+2, color='blue', lw=2, linestyle='-.')
ax.plot(x, x+3, color='blue', lw=2, linestyle=':')

line, =ax.plot(x, x+4, color='black', lw=1.50)
line.set_dashes([5, 10, 15, 10])

# %%
fig, ax = plt.subplots(dpi=100) #figsize=(8,4)

#line width
ax.plot(x, x+1, color='blue', lw=2, linestyle='-')
ax.plot(x, x+2, color='blue', lw=2, linestyle='-.')
ax.plot(x, x+3, color='blue', lw=2, linestyle=':')

line, =ax.plot(x, x+4, color='black', lw=1.50)
line.set_dashes([5, 10, 15, 10])

line, =ax.plot(x, x+5, color='black', lw=1.50)
line.set_dashes([5, 10, 15, 3])

line, =ax.plot(x, x+6, color='black', lw=1.50)
line.set_dashes([5, 10, 30, 30])

# %%
fig, ax = plt.subplots(dpi=100) #figsize=(8,4)

#line width
ax.plot(x, x+1, color='blue', marker='o')
ax.plot(x, x+2, color='blue', marker='+')
ax.plot(x, x+3, color='blue', marker='s')
ax.plot(x, x+4, color='blue', marker='1')

ax.plot(x, x+5, color='blue', marker='o', markersize=2)
ax.plot(x, x+6, color='blue', marker='s', markersize=5, markerfacecolor='red')
ax.plot(x, x+7, color='blue', marker='s', markersize=12, markerfacecolor='green')

# %%
# set the canvas grid and axis range
fig, Axes = plt.subplots(1, 2, figsize=(10,5))
Axes[0].plot(x, x**2, x, x**3, lw=2)
Axes[0].grid(True)

# %%
# set the canvas grid and axis range
fig, Axes = plt.subplots(1, 2, figsize=(10,5))
Axes[0].plot(x, x**2, x, x**3, lw=2)
Axes[0].grid(True)

Axes[1].plot(x, x**2, x, x**3, lw=2)
# If you add "Axes[1].grid(True)" at this step, the graph would have another points (2,5) indicated in the graph
Axes[1].set_ylim([0, 60])
Axes[1].set_xlim([2, 5])
Axes[1].grid(True)

# %% [markdown]
# # other 2D graphics

# %%
n = np.array([0, 1, 2, 3, 4,5])

fig, axes = plt.subplots(1, 4, figsize=(16,5))

# %%
n = np.array([0, 1, 2, 3, 4,5])

fig, axes = plt.subplots(1, 4, figsize=(16,5))
axes[0].set_title('scatter')
axes[0].scatter(x, x+0.25*np.random.randn(len(x)))

# %%
n = np.array([0, 1, 2, 3, 4,5])

fig, axes = plt.subplots(1, 4, figsize=(16,5))
axes[0].set_title('scatter')
axes[0].scatter(x, x+0.25*np.random.randn(len(x)))
axes[1].set_title("step")
axes[1].step(n, n**2, lw=2)

# %%
n = np.array([0, 1, 2, 3, 4,5])

fig, axes = plt.subplots(1, 4, figsize=(16,5))
axes[0].set_title('scatter')
axes[0].scatter(x, x+0.25*np.random.randn(len(x)))

axes[1].set_title("step")
axes[1].step(n, n**2, lw=2)

axes[2].set_title("bar")
axes[2].bar(n, n**2, align="center", width=0.5, alpha=0.5)
# Out:
# <BarContainer object of 6 artists>

# %%
n = np.array([0, 1, 2, 3, 4,5])

fig, axes = plt.subplots(1, 4, figsize=(16,5))
axes[0].set_title('scatter')
axes[0].scatter(x, x+0.25*np.random.randn(len(x)))

axes[1].set_title("step")
axes[1].step(n, n**2, lw=2)

axes[2].set_title("bar")
axes[2].bar(n, n**2, align="center", width=0.9, )
# Out:
# <BarContainer object of 6 artists>

# %%
n = np.array([0, 1, 2, 3, 4,5])

fig, axes = plt.subplots(1, 4, figsize=(16,5))
axes[0].set_title('scatter')
axes[0].scatter(x, x+0.25*np.random.randn(len(x)))

axes[1].set_title("step")
axes[1].step(n, n**2, lw=2)

axes[2].set_title("bar")
axes[2].bar(n, n**2, width=0.9, )

axes[3].set_title("fill_between")
axes[3].fill_between(x, x**2, x**3, color="green", alpha=0.5 )

# %%
#Draw a radar chart
fig = plt.figure(figsize=(6,6))
ax = fig.add_axes([0.0,0.0,0.6,0.6], polar=True)

# %%
#Draw a radar chart
fig = plt.figure(figsize=(6,6))
ax = fig.add_axes([0.0,0.0,0.6,0.6])

# %%
#Draw a radar chart
fig = plt.figure(figsize=(6,6))
ax = fig.add_axes([0.0, 0.0, 1, 1], polar=True)
t = np.linspace(0, 2*np.pi, 100)
ax.plot(t,t*2, color='blue', lw=3)

# %%
# Draw a histogram
n = np.random.randn(100000)
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
axes[0].set_title("Default histogram")
axes[0].hist(n)
# Out:
# (array([   38.,   509.,  3714., 14027., 28559., 30266., 16903.,  5070.,
#           840.,    74.]),
#  array([-4.18035418, -3.36060259, -2.540851  , -1.72109942, -0.90134783,
#         -0.08159624,  0.73815535,  1.55790694,  2.37765853,  3.19741012,
#          4.0171617 ]),
#  <BarContainer object of 10 artists>)

# %%
# Draw a histogram
n = np.random.randn(100000)
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
axes[0].set_title("Default histogram")
axes[0].hist(n)

axes[1].set_title("Cumulative detailed histogram")
axes[1].hist(n, cumulative=True, bins=50)
# Out:
# (array([2.0000e+00, 2.0000e+00, 4.0000e+00, 5.0000e+00, 2.6000e+01,
#         4.0000e+01, 7.4000e+01, 1.2900e+02, 2.0800e+02, 3.9400e+02,
#         6.8100e+02, 1.1070e+03, 1.7460e+03, 2.7430e+03, 4.0760e+03,
#         5.9610e+03, 8.3930e+03, 1.1602e+04, 1.5622e+04, 2.0404e+04,
#         2.5927e+04, 3.2199e+04, 3.9037e+04, 4.6411e+04, 5.3792e+04,
#         6.0971e+04, 6.7741e+04, 7.4034e+04, 7.9677e+04, 8.4518e+04,
#         8.8486e+04, 9.1715e+04, 9.4213e+04, 9.6076e+04, 9.7404e+04,
#         9.8326e+04, 9.8932e+04, 9.9377e+04, 9.9619e+04, 9.9782e+04,
#         9.9879e+04, 9.9939e+04, 9.9969e+04, 9.9985e+04, 9.9994e+04,
#         9.9997e+04, 9.9999e+04, 9.9999e+04, 9.9999e+04, 1.0000e+05]),
#  array([-4.53155974, -4.34619119, -4.16082264, -3.97545409, -3.79008554,
#         -3.60471699, -3.41934844, -3.23397989, -3.04861134, -2.86324279,
#         -2.67787424, -2.49250569, -2.30713714, -2.12176859, -1.93640004,
# ...

# %%
# Draw a histogram
n = np.random.randn(100000)
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
axes[0].set_title("Default histogram")
axes[0].hist(n)

axes[1].set_title("Cumulative detailed histogram")
axes[1].hist(n, cumulative=True,alpha=0.8,  bins=10)
# Out:
# (array([5.0000e+00, 8.2000e+01, 1.2270e+03, 9.4150e+03, 3.5641e+04,
#         7.1759e+04, 9.3520e+04, 9.9289e+04, 9.9964e+04, 1.0000e+05]),
#  array([-5.08445674, -4.14093872, -3.1974207 , -2.25390269, -1.31038467,
#         -0.36686665,  0.57665137,  1.52016938,  2.4636874 ,  3.40720542,
#          4.35072343]),
#  <BarContainer object of 10 artists>)

# %%
# Draw a histogram
n = np.random.randn(100000)
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
axes[0].set_title("Default histogram")
axes[0].hist(n)

axes[1].set_title("Cumulative detailed histogram")
axes[1].hist(n, bins=10)
# Out:
# (array([7.0000e+00, 1.0500e+02, 1.4950e+03, 9.2750e+03, 2.6564e+04,
#         3.4981e+04, 2.0860e+04, 5.9310e+03, 7.3600e+02, 4.6000e+01]),
#  array([-4.89631596, -3.9824123 , -3.06850864, -2.15460498, -1.24070131,
#         -0.32679765,  0.58710601,  1.50100967,  2.41491334,  3.328817  ,
#          4.24272066]),
#  <BarContainer object of 10 artists>)

# %%
# Draw a histogram
n = np.random.randn(100000)
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
axes[0].set_title("Default histogram")
axes[0].hist(n)

axes[1].set_title("Cumulative detailed histogram")
axes[1].hist(n, cumulative=True, bins=10)
# Out:
# (array([1.3000e+01, 3.2100e+02, 3.0020e+03, 1.5605e+04, 4.4050e+04,
#         7.6412e+04, 9.4337e+04, 9.9293e+04, 9.9958e+04, 1.0000e+05]),
#  array([-4.46321446, -3.60053991, -2.73786536, -1.87519081, -1.01251626,
#         -0.14984171,  0.71283285,  1.5755074 ,  2.43818195,  3.3008565 ,
#          4.16353105]),
#  <BarContainer object of 10 artists>)

# %%
# Draw Contour image

import matplotlib
import numpy as np
import matplotlib.cm as cm
import matplotlib.pyplot as plt

delta = 0.025
x = np.arange(-3.0, 3.0, delta)
y = np.arange(-2.0, 2.0, delta)
X, Y = np.meshgrid(x, y)
Z1 = np.exp(-X**2 -Y**2)
Z2 = np.exp(-(X-1)**2 -(Y-1)**2)
Z = (Z1 - Z2)*2
print(X)
print(Y)
# Out:
# [[-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  ...
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]]
# [[-2.    -2.    -2.    ... -2.    -2.    -2.   ]
#  [-1.975 -1.975 -1.975 ... -1.975 -1.975 -1.975]
#  [-1.95  -1.95  -1.95  ... -1.95  -1.95  -1.95 ]
#  ...
#  [ 1.925  1.925  1.925 ...  1.925  1.925  1.925]
#  [ 1.95   1.95   1.95  ...  1.95   1.95   1.95 ]
#  [ 1.975  1.975  1.975 ...  1.975  1.975  1.975]]

# %%
fig, ax = plt.subplots()
CS = ax.contour(X, Y, Z)
ax.clabel(CS, inline=1, fontsize=10)
ax.set_title("contour map")
# Out:
# Text(0.5, 1.0, 'contour map')

# %%
# Draw 3D surface image
from mpl_toolkits.mplot3d.axes3d import get_test_data

fig = plt.figure(figsize=(14,6))

#specify the 3D graphics to draw, with projection = '3D'
ax = fig.add_subplot(1, 2, 1, projection='3d')
ax.plot_surface(X, Y, Z, rstride=4, cstride=4, linewidth=0)

# %%
# Draw 3D surface image
from mpl_toolkits.mplot3d.axes3d import get_test_data

fig = plt.figure(figsize=(14,6))

#specify the 3D graphics to draw, with projection = '3D'
ax = fig.add_subplot(1, 4, 1, projection='3d')
ax.plot_surface(X, Y, Z, rstride=4, cstride=4, linewidth=0)

# %%
# Draw 3D surface image
from mpl_toolkits.mplot3d.axes3d import get_test_data

fig = plt.figure(figsize=(14,6))

#specify the 3D graphics to draw, with projection = '3D'
ax = fig.add_subplot(1, 3, 1, projection='3d')
ax.plot_surface(X, Y, Z, rstride=4, cstride=4, linewidth=0)

# %%
# Draw 3D surface image
from mpl_toolkits.mplot3d.axes3d import get_test_data

fig = plt.figure(figsize=(14,6))

#specify the 3D graphics to draw, with projection = '3D'
ax = fig.add_subplot(2, 7, 1, projection='3d')
ax.plot_surface(X, Y, Z, rstride=4, cstride=4, linewidth=0)

# %%
# heat map ..... color map

# %% [markdown]
# # Practice example
# Write a python programming to create a pie chart of the popularity of programming language

# %%
import matplotlib.pyplot as plt
# data to plot
languages = 'Python', 'Java', 'PHP', 'JavaScript', 'C#', 'C++'
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b']

# %%
# explode 1st slice
explode = (0.1, 0, 0, 0, 0 ,0)
plt.pie(popularity)
# Out:
# ([<matplotlib.patches.Wedge at 0x21eeb499c40>,
# ...
#  [Text(0.6106212455488447, 0.914954476727874, ''),
#   Text(-1.0139237282141302, 0.42656614184011216, ''),
#   Text(-0.7897694469856671, -0.7656789278855424, ''),
#   Text(-0.06323929665114071, -1.0981806733680344, ''),
#   Text(0.654413852726294, -0.8841620379545417, ''),
#   Text(1.0520142924916651, -0.3213501647630839, '')])

# %%
# explode 1st slice
explode = (0.1, 0, 0, 0, 0 ,0)
plt.pie(popularity, explode = explode, labels = languages, colors = colors, autopct='%1.1f%%', shadow=True, startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x21eeb4e2ee0>,
# ...
#  [Text(-1.1518739051683529, -0.33643202373170245, 'Python'),
#   Text(0.5025192070582963, -0.978506232242545, 'Java'),
#   Text(1.0971674240514186, 0.07889007288863878, 'PHP'),
#   Text(0.754341041824552, 0.8006057660415953, 'JavaScript'),
#   Text(0.06701830757132049, 1.0979565321315212, 'C#'),
#   Text(-0.5993297985645449, 0.9223902604389219, 'C++')],
#  [Text(-0.6719264446815391, -0.19625201384349306, '31.3%'),
#   Text(0.2741013856681616, -0.5337306721322972, '24.8%'),
#   Text(0.5984549585735011, 0.043030948848348426, '12.4%'),
#   Text(0.41145875008611926, 0.4366940542045065, '11.3%'),
#   Text(0.036555440493447534, 0.5988853811626479, '10.8%'),
#   Text(-0.3269071628533881, 0.5031219602394119, '9.4%')])

# %%
# explode 1st slice
explode = (0.1, 0, 0, 0, 0 ,0)
plt.pie(popularity, explode = explode, labels = languages, colors = colors, autopct='%1.1f%%', shadow=True, startangle=0)
# Out:
# ([<matplotlib.patches.Wedge at 0x21eeb643f40>,
# ...
#  [Text(0.666132267871467, 0.998132156430408, 'Python'),
#   Text(-1.0139237282141302, 0.42656614184011216, 'Java'),
#   Text(-0.7897694469856671, -0.7656789278855424, 'PHP'),
#   Text(-0.06323929665114071, -1.0981806733680344, 'JavaScript'),
#   Text(0.654413852726294, -0.8841620379545417, 'C#'),
#   Text(1.0520142924916651, -0.3213501647630839, 'C++')],
#  [Text(0.38857715625835565, 0.582243757917738, '31.3%'),
#   Text(-0.5530493062986165, 0.23267244100369752, '24.8%'),
#   Text(-0.43078333471945474, -0.41764305157393217, '12.4%'),
#   Text(-0.03449416180971311, -0.5990076400189277, '11.3%'),
#   Text(0.35695301057797857, -0.48227020252065905, '10.8%'),
#   Text(0.5738259777227264, -0.1752819080525912, '9.4%')])

# %%
# explode 1st slice
explode = (0.1, 0, 0, 0, 0 ,0)
plt.pie(popularity, explode = explode, labels = languages, colors = colors, autopct='%1.1f%%', shadow=True, startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x21eeb726fd0>,
# ...
#  [Text(-0.9981321564304079, 0.6661322678714671, 'Python'),
#   Text(-0.42656614184011216, -1.0139237282141302, 'Java'),
#   Text(0.7656789278855427, -0.7897694469856669, 'PHP'),
#   Text(1.0981806733680344, -0.06323929665114078, 'JavaScript'),
#   Text(0.8841620379545417, 0.6544138527262939, 'C#'),
#   Text(0.321350164763084, 1.0520142924916651, 'C++')],
#  [Text(-0.5822437579177379, 0.38857715625835576, '31.3%'),
#   Text(-0.23267244100369752, -0.5530493062986164, '24.8%'),
#   Text(0.4176430515739324, -0.4307833347194546, '12.4%'),
#   Text(0.5990076400189277, -0.034494161809713146, '11.3%'),
#   Text(0.48227020252065905, 0.3569530105779785, '10.8%'),
#   Text(0.17528190805259122, 0.5738259777227264, '9.4%')])

# %% [markdown]
# # The End
